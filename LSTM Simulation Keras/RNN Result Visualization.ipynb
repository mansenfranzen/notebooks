# %%
import pandas as pd
import pickle
import itertools

from bokeh.plotting import figure, output_notebook, show
from bokeh.palettes import Category10
from bokeh.layouts import gridplot
from bokeh.models import Title

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ef3e0599-44ad-454d-8fd2-0f7ee098b3eb">Loading BokehJS ...</span>
#     </div>

# %%
def extract_scores(result):
    extracted = {}
    for kind in ("train_", "test_"):
        for score in ("AUC", "F1 Max"):
            extracted[kind + score] = result[kind + "res"][score]

    extracted.update({k:v for k, v in result.items() if not k.endswith("res")})
    return extracted

# %%
results = pickle.load(open("BinaryF.p", "rb"))
scores = [extract_scores(x) for x in results]

df = pd.DataFrame(scores)
df.head()
# Out:
#    duration  epochs model sequence  size  test_AUC  test_F1 Max  train_AUC  \
# 0  9.335835       1    L5   (3, 1)  10^5  0.453976     0.117137   0.449026
# 1  7.733341       2    L5   (3, 1)  10^5  0.513589     0.118988   0.516810
# 2  7.882221       3    L5   (3, 1)  10^5  0.571297     0.138604   0.578429
# 3  7.754082       4    L5   (3, 1)  10^5  0.718298     0.212551   0.724985
# 4  8.123513       5    L5   (3, 1)  10^5  0.746254     0.233888   0.752928
#
#    train_F1 Max
# 0      0.115465
# 1      0.118044
# 2      0.135557
# 3      0.211710
# 4      0.231837

# %%
model_order = ["L5", "L10_L5", "L30_L15", "L15_L10_L5", "L30_L20_L10"]
sequence_order = ["(3, 1)", "(4, 1, 3)"]

df["model"] = pd.Categorical(df["model"], model_order)
df["sequence"] = pd.Categorical(df["sequence"].astype(str), sequence_order)
# Out:
# [('(3, 1)', 'L5'),
#  ('(3, 1)', 'L10_L5'),
#  ('(3, 1)', 'L30_L15'),
#  ('(3, 1)', 'L15_L10_L5'),
#  ('(3, 1)', 'L30_L20_L10'),
#  ('(4, 1, 3)', 'L5'),
#  ('(4, 1, 3)', 'L10_L5'),
#  ('(4, 1, 3)', 'L30_L15'),
#  ('(4, 1, 3)', 'L15_L10_L5'),
#  ('(4, 1, 3)', 'L30_L20_L10')]

# %%
width = 200
height = 125

def create_sub_plot(sub_df):
    p = figure(y_range=(-0.1, 1.1), width=width, height=height)

    for (size, size_df), color in zip(sub_df.groupby("size"), Category10[10]):
        series = size_df.groupby("epochs")["test_F1 Max"].mean().sort_index()
        p.line(x=series.index, y=series.values, line_color=color, legend=size)
        p.circle(x=series.index, y=series.values, line_color=color, fill_color=color, legend=size)
    
    p.yaxis.minor_tick_line_color = None
    p.xaxis.minor_tick_line_color = None
    p.xaxis.axis_label = "Epochs"
    p.yaxis.axis_label = "F1 Score"
    
    return p

# %%
plots = []
for idx, ((model, sequence), sub_df) in enumerate(df.groupby(["model", "sequence"])):

    p = create_sub_plot(sub_df)
    if idx % 2 == 0:
        p.add_layout(Title(text=model, align="center"), "left") 
        p.plot_width = width + 50
    else:
        p.yaxis.visible = False
        
    if idx >= 8:
        p.add_layout(Title(text=sequence, align="center"), "below")  
        p.plot_height = height + 50
    else:
        p.xaxis.visible = False
        
    if idx != 1:
        p.legend.visible = False
        
    plots.append(p)

# %%
show(gridplot(plots, ncols=2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7abb68f-f8a0-4b42-ae35-edc41caf573b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f7abb68f-f8a0-4b42-ae35-edc41caf573b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7abb68f-f8a0-4b42-ae35-edc41caf573b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7abb68f-f8a0-4b42-ae35-edc41caf573b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"302cd3be-77d7-4b94-ae85-227f4d9aa9a0":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e455d087-a47b-43aa-ba60-92f7cc76cb6e","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":{"__ndarray__":"WxGEQGC2zz8AAAAAAADwPwAAAAAAAPA/AAAAAAAA8D8AAAAAAADwPw==","dtype":"float64","shape":[5]}}},"id":"13dfbeb7-e893-4888-ae6b-e9f1ed81c114","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3,4,5],"y":{"__ndarray__":"BkA+ypZ32D8wJ8sV8f7vPwAAAAAAAPA/AAAAAAAA8D8AAAAAAADwPw==","dtype":"float64","shape":[5]}}},"id":"f3d1f131-1c3b-4c2c-9a98-87980ac8c004","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bb4be630-d361-49f6-becd-a9e3eea4d16d","type":"PanTool"},{"id":"bcdcc6b2-e14a-4884-bc3b-8c187204c425","type":"WheelZoomTool"},{"id":"1f0609f7-329d-40d0-8603-d3acbe470a49","type":"BoxZoomTool"},{"id":"fc1d553e-510b-4f2c-9c17-5a222fc2a86d","type":"SaveTool"},{"id":"e75f264a-a7fe-4222-a834-f5d91a664d89","type":"ResetTool"},{"id":"48a1891f-fbe3-4715-96e2-8492bf442bda","type":"HelpTool"}]},"id":"a93bc2ec-4ba4-4ca9-ae9d-8e3146a226dc","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"63e74dab-bdbb-4180-90ac-cb7d959c8199","type":"Line"},{"attributes":{"callback":null},"id":"4e528cc8-5361-4abe-a28d-a8bd61d7049d","type":"DataRange1d"},{"attributes":{"callback":null,"end":1.1,"start":-0.1},"id":"d54ff4f8-8acd-45c2-9e61-c1fe5166813d","type":"Range1d"},{"attributes":{"axis_label":"F1 Score","formatter":{"id":"25a9724b-8885-4ede-bacb-53c8f697897e","type":"BasicTickFormatter"},"minor_tick_line_color":{"value":null},"plot":{"id":"41836b16-09c6-4602-be86-fdd738ce5cad","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f34abb8-d1c3-45c7-9c61-3d65561ec46a","type":"BasicTicker"},"visible":false},"id":"29d19b0a-6454-47d6-8592-c2ce28c78f73","type":"LinearAxis"},{"attributes":{"align":"center","plot":{"id":"d5b845d9-f9ed-4669-872c-b3b723b2eaad","subtype":"Figure","type":"Plot"},"text":"L30_L20_L10"},"id":"c5810c7b-04ec-4b78-a8e4-0f1d1005eb1f","type":"Title"},{"attributes":{"fill_color":{"value":"#2ca02c"},"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac274552-1187-4fae-97c8-ffc916d30175","type":"Circle"},{"attributes":{"data_source":{"id":"becd97ff-2271-4a12-accc-5f34c1ae3234","type":"ColumnDataSource"},"glyph":{"id":"775af688-77c9-4378-b47b-4fa3bc871e78","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ab9900b7-a5ae-41ee-9ca4-32c3a5994c65","type":"Circle"},"selection_glyph":null},"id":"98485bd4-a71a-4a70-8576-27cdb63eadb2","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0dfd022f-e21b-4378-9a5b-4ad5b7051e33","type":"PanTool"},{"id":"db6596b9-d01a-4899-8a7c-2b3a9dbf69fe","type":"WheelZoomTool"},{"id":"87db1243-ce2e-4523-9636-6fc56c76ee0c","type":"BoxZoomTool"},{"id":"ba1a0d3a-a075-4b30-8075-cc6d4f26352d","type":"SaveTool"},{"id":"7c3a02f2-3afd-4b9a-b48b-980d7e3fa339","type":"ResetTool"},{"id":"a77c7253-d1a8-4da3-b515-994003756edc","type":"HelpTool"}]},"id":"175576b2-9768-45d0-8d32-645414874c67","type":"Toolbar"},{"attributes":{"data_source":{"id":"4cecd413-8457-480e-a0fe-c6db4760892e","type":"ColumnDataSource"},"glyph":{"id":"fb35b7b6-9cf2-49a5-a264-dc0ed72dee66","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0971b149-341d-4d88-ba73-1a4b561dc48e","type":"Circle"},"selection_glyph":null},"id":"adb86497-bb64-4ec3-9cc3-54672839fc63","type":"GlyphRenderer"},{"attributes":{},"id":"a1f55dc8-a74d-462e-b895-6af8dd07ef02","type":"BasicTicker"},{"attributes":{},"id":"771338e5-01f2-4d99-89e3-6a5359a9bbaf","type":"BasicTickFormatter"},{"attribute ...
